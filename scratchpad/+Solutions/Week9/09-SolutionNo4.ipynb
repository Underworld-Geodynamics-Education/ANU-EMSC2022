# %% [markdown]
# # Exercise 4
#
# Make a graph the Age / Depth relationship for the global oceans
#
# Let's discuss if this makes sense !

# %%
# First we import the modules we need

import cartopy
import cartopy.crs as ccrs
import matplotlib
import matplotlib.pyplot as plt

# The universal solvent for arrays (and hence images).
import numpy as np

# %% [markdown]
# ## Read in the data

# %%
## Read the data

age_depth = np.load("../+Data/OceanAgeDepth.npz")
print(age_depth.files)

lons = age_depth["lons"]
lats = age_depth["lats"]
age  = age_depth["age"]
depth = age_depth["depth"]
# Out:
# ['lons', 'lats', 'depth', 'age']

# %%
fig = plt.figure(figsize=(12, 12), facecolor="none")
ax  = plt.subplot(111)

ax.scatter(age, depth, s=1.0, alpha=0.25)

ax.set_xlim([0.0,200.0])
ax.set_ylim([-7500.0,200.0])
pass

# %% [markdown]
# ## Plot a histogram of ocean plate age
#
# You will need to use the `ax.hist` function

# %%
fig = plt.figure(figsize=(12, 12), facecolor="none")
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)


ax1.hist(age, bins=18, density=True, histtype='stepfilled', cumulative=True )
ax2.hist(age, bins=18, density=True, histtype='stepfilled' )



pass

# %% [markdown]
# #
